# %%
from tqdm.contrib.concurrent import thread_map
from itertools import product
import python.Utils.Download
import python.Utils.FilePaths

def download_gfw_voyages_parallel(token, years=range(2017, 2026), months=range(1, 13), prefix="voyages", max_workers=6):
    base_url = "https://gateway.api.globalfishingwatch.org/v3/download/datasets/public-voyages-confidence-4:v20220922/download"
    headers = {"Authorization": f"Bearer {token}"}

    all_files = [(year, month) for year, month in product(years, months)]

    def download_wrapper(year_month):
        year, month = year_month
        file_name = f"{prefix}_{year}{month:02d}.csv"
        signed_url = python.Utils.Download.get_signed_url(base_url, headers, file_name)
        if signed_url is None:
            return f"No signe URL for {file_name}"
        python.Utils.Download.download_file_from_signed_url(signed_url, file_name, python.Utils.FilePaths.VOYAGES_DIR)
        return f"Finished download of {file_name}"

    results = thread_map(download_wrapper, all_files, max_workers=max_workers, desc="Downloading files")
    for r in results:
        print(r)

# %%
TOKEN = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6ImtpZEtleSJ9..WmhPLS98QHTZq642io4Ajo8fdc9rqNKHuLdwZFiyAg7FPyN7oO8Ro9aBKsTZ-L6qhj-DoIGnnm2KlbF3SkBETLrET0Yw27Pi9SY4-xIEp1LRMqh9hN3Z5dk-xyLWu9kOreSS-BWh6uE9abT_P_dWSE3VeaUKUAsPA2frR6i3mQuN4w41xSrzQ6D5JyHekSKKN8XeRPc8kbPMQ9aDC4KLB0Q5fWVOBPboIjLU7_53BXSFtaNqj3nskCy4T6DJE7VVZau2BxwsudIQdhnKzOtCNUeA9oOhuQmc4CL0NPu-B0YxhxY8M7y8F825uupiFAfYpB1sWNrZACnwXckta2oPJvinsGsAQgCpCtdnHKoGucFH5N23TVoVy-V4aeYwXXnL2fYZzPp0BUWAZYmHFgWPG4KCowEd6njPqtr3XAVKSnpWDt9Onrpl041C7_gc86rrTmkqmahgNGrQEbzBT7vy9G0Yfc_Kfi4yA5s4TkWRCy3ckcsvNSPYW5V0cnPWmwOd"

download_gfw_voyages_parallel(TOKEN, range(2021, 2026))
# Out:
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202102.csv
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202106.csv
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202101.csv
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202105.csv
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202103.csv
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202104.csv
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202107.csv
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202110.csv
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202111.csv
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202112.csv
# ...
# File saved: D:\Bootcamp\Projects\Capstone_1\files\data\lfs\voyages\voyages_202108.csv
# ...

# %%
from ruhken_utils import eda

# %%
import python.Utils.FilePaths
import python.Utils.Download


def download_gfw_voyages(token, years=range(2017, 2026), months=range(1,13), prefix="voyages"):
    """
    Automatically downloads GFW voyages data for the given years and months.

    Args:
        token (str): GFW API Bearer Token
        years (iterable): Years >= 2017, e.g. range(2017, 2025)
        months (iterable): Months without zero indexing, e.G. range(1,13)
        prefix (str): Dateiname prefix, standardmäßig 'voyages'
    """
    base_url = "https://gateway.api.globalfishingwatch.org/v3/download/datasets/public-voyages-confidence-4:v20220922/download"
    headers = {"Authorization": f"Bearer {token}"}

    for year in years:
        for month in months:
            file_name = f"{prefix}_{year}{month:02d}.csv"
            print(f"Preparing download for {file_name}...")

            signed_url = python.Utils.Download.get_signed_url(base_url, headers, file_name)

            if signed_url is None:
                continue

            print(f"Successfully found signed_url for {file_name}...")

            python.Utils.Download.download_file_from_signed_url(signed_url, file_name, python.Utils.FilePaths.VOYAGES_DIR)

# %% [markdown]
# # Download Voyage Data
