# %%
import pandas
from python.Utils import FilePaths
import ruhken_utils as ru



df = pandas.read_csv(FilePaths.VOYAGES_DIR / "voyages_201701.csv")

# %%
ru.explore_features(df)
# Out:
# ID  Name                       non-null count   D-Type  Feature Summary
# 0   mmsi                       892025 non-null  int64   138932 unique | Min: 2.00, Max: 1073741823.00, Q1: 249809000.00, Median: 370153000.00, Q3: 431003028.00, Mean: 373882324.94
# 1   vessel_id                  892025 non-null  str     746a3d7e8-88d5-7624-bfa1-272c59e7e500 (731), e354c69f5-5256-3d36-4c0a-771918be0d04 (704), 4eb62218b-b0b9-682c-7895-e010eedadeac (688), e8b17ef86-6d83-d5b9-eda0-83e1a08ba376 (688), b786475b0-0662-720d-587a-0c1aa9492891 (632)
# 2   trip_id                    892025 non-null  str     only unique Values
# 3   trip_start                 892025 non-null  str     0001-02-03 00:00:00 UTC (11920), 2017-01-25 17:00:00 UTC (9), 2017-01-13 07:30:02 UTC (9), 2017-01-10 04:50:05 UTC (9), 2017-01-14 15:25:00 UTC (8)
# ...
