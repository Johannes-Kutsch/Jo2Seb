# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import FunctionTransformer
# %load_ext autoreload
# %autoreload 2

import json
import mlflow
from mlflow.models import infer_signature

import pandas
import pandas as pd
from ruhken_utils import explore_features, PredictiveImputer, explore_dataframe
from sklearn.pipeline import Pipeline

from Utils import FilePaths
import ruhken_utils as ru
import requests

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.base import BaseEstimator, RegressorMixin

from sklearn.base import BaseEstimator, RegressorMixin
from statsmodels.tsa.statespace.sarimax import SARIMAX
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # rough EDA

# %% [markdown]
# #### Preprocess and fill missing Values

# %%
df = pandas.read_csv(FilePaths.UWB_DATA / "Station_857_2018-01-01--2025-12-31.csv")
components_meta = pandas.read_csv(FilePaths.UWB_METADATA / "UWB_components_metadata.csv")

# %%
def get_component_metadata(component_id: int):
    return components_meta.loc[components_meta["component_id"] == component_id].squeeze()

def interpolate_linear(X):
    X_interp = pd.DataFrame(X).interpolate(method='linear', limit_direction='both')
    return X_interp.values

interpolator = FunctionTransformer(interpolate_linear)

component_columns = ["NO2", "SO2", "PM10"]

component_nan_interpolator = ColumnTransformer(
    transformers=[
        ("interpolate_nan", interpolator, component_columns)
    ],
    remainder="drop"
)

# %%
preprocess_pipe = Pipeline([
    ("rename_features", ru.FeatureRenameTransformer({
        "5": get_component_metadata(5)["component_code"],
        "4": get_component_metadata(4)["component_code"],
        "1": get_component_metadata(1)["component_code"],
        "date_start": "date",
    })),
    ("date_type", ru.ValueTypeCastDatetimeTransformer("date")),
])

df_trans = preprocess_pipe.fit_transform(df)

component_pip = Pipeline([
    ("interpolate_columns", component_nan_interpolator)
])

df_trans[component_columns] = pd.DataFrame(component_pip.fit_transform(df_trans), columns=component_columns)

# %% [markdown]
# #### Check if Dates are continuous

# %%
df_trans = df_trans.sort_values('date').reset_index(drop=True)
date_diff = df_trans['date'].diff()
print(f"Distance between dates are: {date_diff.unique()[1:]}")
# Out:
# Distance between dates are: <TimedeltaArray>
# ['0 days 01:00:00']
# Length: 1, dtype: timedelta64[ns]

# %% [markdown]
# # Models

# %% [markdown]
# ### Setup

# %% [markdown]
# #### MLFLOW

# %%
# Start server with: mlflow server --host localhost --port 5000

mlflow.set_tracking_uri(uri="http://localhost:5000")
experiment = mlflow.set_experiment("PM10")

# %% [markdown]
# #### Eval Function

# %%
def evaluate_timeseries_pipeline(X, y, pipeline, n_splits=5, model_name = "", params = None):
    """
    Evaluates a scikit-learn pipeline on a time series using TimeSeriesSplit.

    Parameters:
    - X: pd.DataFrame, Feature matrix
    - y: pd.Series, Target variable
    - pipeline: sklearn Pipeline or estimator with fit/predict
    - n_splits: int, number of splits for TimeSeriesSplit
    - model_name: str, name of the model

    Returns:
    - results: list of dicts with split info and metrics
    """

    with mlflow.start_run(run_name=f"{model_name}_cv{n_splits}"):
        time_series_splits = TimeSeriesSplit(n_splits=n_splits)
        results = []
        for i, (train_index, test_index) in enumerate(time_series_splits.split(X)):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            pipeline.fit(X_train, y_train)

            y_pred = pipeline.predict(X_test)
            pred_nan_mask = ~np.isnan(y_pred)

            y_pred = y_pred[pred_nan_mask]
            y_test = y_test.values[pred_nan_mask]

            mae = mean_absolute_error(y_test, y_pred)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))

            results.append({
                "split": i+1,
                "train_size": len(train_index),
                "test_size": len(test_index),
                "mae": mae,
                "rmse": rmse,
                "y_test": y_test,
                "y_pred": y_pred
            })

        signature = infer_signature(X_test[pred_nan_mask], y_pred)

        if params is not None:
            mlflow.log_params(params)

        mlflow.log_metric("mae", get_avg_score(results, "mae"))
        mlflow.log_metric("rmse", get_avg_score(results, "rmse"))
        mlflow.sklearn.log_model(sk_model=pipeline, name=model_name, signature=signature)

def get_avg_score(results, key) -> float:
    return np.mean([r[key] for r in results])

# %% [markdown]
# ### Baseline Models

# %% [markdown]
# #### Predict Always Mean

# %%
class MeanBaseline(BaseEstimator, RegressorMixin):
    def fit(self, X, y):
        self.mean_ = y.mean()
        return self

    def predict(self, X):
        return np.full(shape=(len(X),), fill_value=self.mean_)

X = df_trans[['PM10']]
y = df_trans['PM10']

baseline_pipeline = MeanBaseline()
evaluate_timeseries_pipeline(X, y, baseline_pipeline, n_splits=5, model_name="Baseline_Mean")
# Out:
# 2026/03/10 14:49:52 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Baseline_Mean_cv5 at: http://localhost:5000/#/experiments/1/runs/c7fb2cf0b0ff4e65bc302caff435a3d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# #### Persistence / Naive Forecast / PM10(t+1) = PM10(t)

# %%
import numpy as np
from sklearn.base import BaseEstimator, RegressorMixin

class PersistenceBaseline(BaseEstimator, RegressorMixin):
    def fit(self, X, y):
        return self

    def predict(self, X):
        last_values = X['PM10'].shift(1)
        return last_values.values

X = df_trans[['PM10']]
y = df_trans['PM10']

baseline_pipeline = PersistenceBaseline()
evaluate_timeseries_pipeline(X, y, baseline_pipeline, n_splits=5, model_name="Baseline_T+1")
# Out:
# 2026/03/10 14:49:55 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Baseline_T+1_cv5 at: http://localhost:5000/#/experiments/1/runs/4d6cdb119257429fadcbec090883d2c5
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# ### Temporal Features

# %% [markdown]
# #### Sarimax

# %%
class SARIMABaseline(BaseEstimator, RegressorMixin):
    def __init__(self,
                 order=(1,1,1),
                 seasonal_order=(1,0,1,24)):
        self.order = order
        self.seasonal_order = seasonal_order

    def fit(self, X, y):
        self.model_ = SARIMAX(
            y,
            order=self.order,
            seasonal_order=self.seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        self.results_ = self.model_.fit(disp=False)
        return self

    def predict(self, X):
        start = len(self.results_.data.endog)
        end = start + len(X) - 1
        forecast = self.results_.predict(start=start, end=end)
        return forecast

X = df_trans[['PM10']]
y = df_trans['PM10']

train_size = int(len(y) * 0.02)
y = y.iloc[:train_size]
X = X.iloc[:train_size]

sarima_model = SARIMABaseline(
    order=(2,1,0),
    seasonal_order=(1,0,0,24)
)

evaluate_timeseries_pipeline(
    X,
    y,
    sarima_model,
    n_splits=5,
    model_name="SARIMAX",
    params={"order": sarima_model.order, "seasonal_order": sarima_model.seasonal_order}
)
# Out:
# 2026/03/10 14:50:23 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run SARIMAX_cv5 at: http://localhost:5000/#/experiments/1/runs/8db6942c6b084aa38ba81be828e7600d
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
import pmdarima as pm

train_size = int(len(y) * 0.01)
y_train = y.iloc[:train_size]

model = pm.auto_arima(
    y_train,
    seasonal=True,
    m=24,
    trace=True,
    error_action="ignore",
    suppress_warnings=True,
    stepwise=True
)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[24] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(0,1,0)(0,0,0)[24] intercept   : AIC=4267.671, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[24] intercept   : AIC=4266.029, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,1)[24] intercept   : AIC=4262.390, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[24]             : AIC=4265.673, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[24] intercept   : AIC=4261.664, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,0)[24] intercept   : AIC=4262.237, Time=0.28 sec
#  ARIMA(0,1,1)(1,0,1)[24] intercept   : AIC=inf, Time=2.14 sec
#  ARIMA(1,1,1)(0,0,0)[24] intercept   : AIC=4232.734, Time=0.16 sec
#  ARIMA(1,1,1)(1,0,0)[24] intercept   : AIC=4233.348, Time=0.95 sec
#  ARIMA(1,1,1)(0,0,1)[24] intercept   : AIC=4233.473, Time=1.10 sec
#  ARIMA(1,1,1)(1,0,1)[24] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(1,1,0)(0,0,0)[24] intercept   : AIC=4264.954, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[24] intercept   : AIC=4233.391, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[24] intercept   : AIC=4236.430, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[24] intercept   : AIC=4236.587, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,0)[24] intercept   : AIC=4232.587, Time=0.05 sec
#  ARIMA(2,1,0)(1,0,0)[24] intercept   : AIC=4230.998, Time=0.41 sec
#  ARIMA(2,1,0)(2,0,0)[24] intercept   : AIC=4231.192, Time=1.57 sec
#  ARIMA(2,1,0)(1,0,1)[24] intercept   : AIC=inf, Time=2.18 sec
#  ARIMA(2,1,0)(0,0,1)[24] intercept   : AIC=4231.338, Time=0.34 sec
#  ARIMA(2,1,0)(2,0,1)[24] intercept   : AIC=inf, Time=7.71 sec
#  ARIMA(3,1,0)(1,0,0)[24] intercept   : AIC=4231.728, Time=0.50 sec
#  ARIMA(2,1,1)(1,0,0)[24] intercept   : AIC=4231.794, Time=0.54 sec
#  ARIMA(3,1,1)(1,0,0)[24] intercept   : AIC=4233.719, Time=1.03 sec
#  ARIMA(2,1,0)(1,0,0)[24]             : AIC=4229.000, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[24]             : AIC=4230.589, Time=0.03 sec
#  ARIMA(2,1,0)(2,0,0)[24]             : AIC=4229.195, Time=0.56 sec
#  ARIMA(2,1,0)(1,0,1)[24]             : AIC=inf, Time=1.72 sec
#  ARIMA(2,1,0)(0,0,1)[24]             : AIC=4229.340, Time=0.17 sec
#  ARIMA(2,1,0)(2,0,1)[24]             : AIC=inf, Time=7.33 sec
#  ARIMA(1,1,0)(1,0,0)[24]             : AIC=4264.030, Time=0.11 sec
#  ARIMA(3,1,0)(1,0,0)[24]             : AIC=4229.730, Time=0.19 sec
#  ARIMA(2,1,1)(1,0,0)[24]             : AIC=4229.797, Time=0.26 sec
#  ARIMA(1,1,1)(1,0,0)[24]             : AIC=4231.376, Time=0.37 sec
#  ARIMA(3,1,1)(1,0,0)[24]             : AIC=4231.721, Time=0.40 sec
#
# Best model:  ARIMA(2,1,0)(1,0,0)[24]
# Total fit time: 36.084 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  701
# Model:             SARIMAX(2, 1, 0)x(1, 0, 0, 24)   Log Likelihood               -2110.500
# Date:                            Tue, 10 Mar 2026   AIC                           4229.000
# Time:                                    14:46:11   BIC                           4247.205
# Sample:                                         0   HQIC                          4236.037
#                                             - 701
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1093      0.009    -11.763      0.000      -0.127      -0.091
# ar.L2         -0.2306      0.027     -8.688      0.000      -0.283      -0.179
# ar.S.L24       0.0731      0.036      2.034      0.042       0.003       0.144
# sigma2        24.3315      0.226    107.842      0.000      23.889      24.774
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):            125076.13
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.28   Skew:                             2.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                        68.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
